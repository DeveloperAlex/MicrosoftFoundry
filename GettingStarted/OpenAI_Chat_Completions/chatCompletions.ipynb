# %% [markdown]
# ## Calling our OpenAI Model from Microsoft Foundry

# %% [markdown]
# ### Installing Required Libraries

# %%
# %pip install azure-ai-projects==2.0.0b2 openai==1.109.1 python-dotenv azure-identity

# %% [markdown]
# ### Setting up the Environment Variables

# %%
import os
from dotenv import load_dotenv
from azure.identity import DefaultAzureCredential
from azure.ai.projects import AIProjectClient
load_dotenv()

foundry_project_endpoint = os.getenv("FOUNDRY_PROJECT_ENDPOINT")
model_deployment_name = os.getenv("MODEL_DEPLOYMENT_NAME")

# %% [markdown]
# ### Setting up the AI Foundry Project Client

# %%
project_client = AIProjectClient(
    endpoint=foundry_project_endpoint,
    credential=DefaultAzureCredential()
)

# %% [markdown]
# ### Setting up the OpenAI Client

# %%
openai_client = project_client.get_openai_client()

print(model_deployment_name)
# Out:
# gpt-5-nano

# %% [markdown]
# ### Sending a Request to the OpenAI Model

# %%
# az login
# Out:
#   Cell In[7], line 1
#     az login
#        ^
# SyntaxError: invalid syntax

# %%
response = openai_client.responses.create(
    model=model_deployment_name,
    instructions="You are a helpful AI assistant.",
    input = "Can you tell me about Microsoft Foundry?"
)

print(f"Response output: {response.output_text}")
print(model_deployment_name)
# Out:
# Response output: I’m not aware of a publicly released Microsoft product specifically named “Microsoft Foundry” as of my latest data (June 2024). It could be:
#
# - an internal code name for a Microsoft project that hasn’t been publicly announced yet,
# - a third‑party product or partner offering that runs on Microsoft Azure,
# - or a mislabeling/confusion with another Microsoft product (like Fabric, Copilot, etc.).
#
# If you can share where you saw the term (a link, a conference slide, a news article, or a specific product area), I can pin down what it refers to and give you a clear summary.
#
# In the meantime, here are some closely related Microsoft offerings you might be thinking of:
#
# - Microsoft Fabric: an integrated analytics platform for data engineering, data science, and data analytics across the Microsoft ecosystem.
# - Copilot family: AI copilots for Microsoft 365, Dynamics 365, Power Platform, GitHub, etc.
# - Azure OpenAI Service: building AI-powered apps with OpenAI models on Azure.
# - Power Platform: low-code tools for building apps with AI features.
# - Visual Studio / GitHub: developer tooling and collaboration with AI-assisted features.
#
# If you share a link or more context (industry, product area, or where you heard it), I’ll give a precise explanation and how it relates to these Microsoft offerings. And I can look up the latest details if you’d like me to fetch current info.
# gpt-5-nano
